# %% [markdown]
# <a href="https://colab.research.google.com/github/aamir-ansari-44/Delhivery_data_analysis/blob/main/Delhivery_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **📦 Delhivery Data Analysis**
#
# downloading the dataset

# %%
# !wget https://drive.google.com/uc?id=12cyX1cS1pnzJHXP1U9tdWNyR4aFqHYq9 -O delhivery_data.csv
# Out:
# --2025-08-03 14:27:38--  https://drive.google.com/uc?id=12cyX1cS1pnzJHXP1U9tdWNyR4aFqHYq9
# Resolving drive.google.com (drive.google.com)... 173.194.69.100, 173.194.69.102, 173.194.69.113, ...
# Connecting to drive.google.com (drive.google.com)|173.194.69.100|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=12cyX1cS1pnzJHXP1U9tdWNyR4aFqHYq9 [following]
# --2025-08-03 14:27:38--  https://drive.usercontent.google.com/download?id=12cyX1cS1pnzJHXP1U9tdWNyR4aFqHYq9
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 108.177.119.132, 2a00:1450:4013:c00::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|108.177.119.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 55617130 (53M) [application/octet-stream]
# Saving to: ‘delhivery_data.csv’
#
# delhivery_data.csv  100%[===================>]  53.04M  69.8MB/s    in 0.8s
#
# ...

# %% [markdown]
# # **Introduction**
#
# Delhivery stands as India’s largest and fastest-growing fully integrated logistics provider by revenue in Fiscal Year 2021. The company is committed to building the operating system for commerce by leveraging a combination of world-class infrastructure, high-quality logistics operations, and advanced engineering and technology capabilities.
#
# The Data team at Delhivery plays a pivotal role in harnessing the vast volumes of operational data to generate intelligence and build capabilities. These efforts are aimed at enhancing the quality, efficiency, and profitability of the business, thereby establishing a competitive edge in the logistics sector.
#
# # **Problem Statement**
#
# Delhivery seeks to gain deeper insights from the data generated by its data engineering pipelines. The primary objectives include:
#
# Cleaning, sanitizing, and transforming raw data fields to extract meaningful and usable features.
# Interpreting and structuring the raw data to support the Data Science team in developing robust forecasting models.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **# 1 Basic EDA and Handling Missing Values**

# %%
df=pd.read_csv('delhivery_data.csv')
df.head(10)
# Out:
#        data          trip_creation_time  \
# 0  training  2018-09-20 02:35:36.476840
# 1  training  2018-09-20 02:35:36.476840
# 2  training  2018-09-20 02:35:36.476840
# 3  training  2018-09-20 02:35:36.476840
# 4  training  2018-09-20 02:35:36.476840
# 5  training  2018-09-20 02:35:36.476840
# 6  training  2018-09-20 02:35:36.476840
# 7  training  2018-09-20 02:35:36.476840
# 8  training  2018-09-20 02:35:36.476840
# 9  training  2018-09-20 02:35:36.476840
#
#                                  route_schedule_uuid route_type  \
# 0  thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 1  thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 2  thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 3  thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 4  thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 5  thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 6  thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144867 entries, 0 to 144866
# Data columns (total 24 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   data                            144867 non-null  object
#  1   trip_creation_time              144867 non-null  object
#  2   route_schedule_uuid             144867 non-null  object
#  3   route_type                      144867 non-null  object
#  4   trip_uuid                       144867 non-null  object
#  5   source_center                   144867 non-null  object
#  6   source_name                     144574 non-null  object
#  7   destination_center              144867 non-null  object
#  8   destination_name                144606 non-null  object
#  9   od_start_time                   144867 non-null  object
#  10  od_end_time                     144867 non-null  object
#  11  start_scan_to_end_scan          144867 non-null  float64
# ...

# %%
df.describe()
# Out:
#        start_scan_to_end_scan  cutoff_factor  actual_distance_to_destination  \
# count           144867.000000  144867.000000                   144867.000000
# mean               961.262986     232.926567                      234.073372
# std               1037.012769     344.755577                      344.990009
# min                 20.000000       9.000000                        9.000045
# 25%                161.000000      22.000000                       23.355874
# 50%                449.000000      66.000000                       66.126571
# 75%               1634.000000     286.000000                      286.708875
# max               7898.000000    1927.000000                     1927.447705
#
#          actual_time      osrm_time  osrm_distance         factor  \
# count  144867.000000  144867.000000  144867.000000  144867.000000
# mean      416.927527     213.868272     284.771297       2.120107
# std       598.103621     308.011085     421.119294       1.715421
# ...

# %%
print(f'Number of rows : {df.shape[0]}, Number of columns : {df.shape[1]}')
print('Number of rows containing training data : ',df[df['data']=='training'].shape[0])
print('Number of rows containing testing data : ',df[df['data']!='test'].shape[0])
print('Percentage of training data:', df[df['data']=='training'].shape[0]*100/(df[df['data']=='training'].shape[0]+df[df['data']!='test'].shape[0]))
# Out:
# Number of rows : 144867, Number of columns : 24
# Number of rows containing training data :  104858
# Number of rows containing testing data :  104858
# Percentage of training data: 50.0

# %%
# percentage of data which are NaN (Not a Number) or None values
df.isna().sum()*100/len(df)
# Out:
# data                              0.000000
# trip_creation_time                0.000000
# route_schedule_uuid               0.000000
# route_type                        0.000000
# trip_uuid                         0.000000
# source_center                     0.000000
# source_name                       0.202254
# destination_center                0.000000
# destination_name                  0.180165
# od_start_time                     0.000000
# od_end_time                       0.000000
# start_scan_to_end_scan            0.000000
# is_cutoff                         0.000000
# cutoff_factor                     0.000000
# cutoff_timestamp                  0.000000
# actual_distance_to_destination    0.000000
# actual_time                       0.000000
# osrm_time                         0.000000
# osrm_distance                     0.000000
# factor                            0.000000
# segment_actual_time               0.000000
# segment_osrm_time                 0.000000
# ...

# %% [markdown]
# Since, the missing values are present only in 2 features source_name and destination_name, their percentages are 0.2%
# and 0.18%, therefore let’s drop these feature's rows.

# %%
df = df.dropna(how='any')
df = df.reset_index(drop=True)
df.isna().sum()*100/len(df)
# Out:
# data                              0.0
# trip_creation_time                0.0
# route_schedule_uuid               0.0
# route_type                        0.0
# trip_uuid                         0.0
# source_center                     0.0
# source_name                       0.0
# destination_center                0.0
# destination_name                  0.0
# od_start_time                     0.0
# od_end_time                       0.0
# start_scan_to_end_scan            0.0
# is_cutoff                         0.0
# cutoff_factor                     0.0
# cutoff_timestamp                  0.0
# actual_distance_to_destination    0.0
# actual_time                       0.0
# osrm_time                         0.0
# osrm_distance                     0.0
# factor                            0.0
# segment_actual_time               0.0
# segment_osrm_time                 0.0
# segment_osrm_distance             0.0
# segment_factor                    0.0
# dtype: float64

# %% [markdown]
# **To ensure accurate data processing, it is essential to convert the data types of time-related columns appropriately.**

# %%
df['trip_creation_time'] = pd.to_datetime(df['trip_creation_time'])
df['od_start_time'] = pd.to_datetime(df['od_start_time'])
df['od_end_time'] = pd.to_datetime(df['od_end_time'])
df['cutoff_timestamp'] = pd.to_datetime(df['cutoff_timestamp'], format="mixed") # this row contains data some with microseconds, some without
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144316 entries, 0 to 144315
# Data columns (total 24 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   data                            144316 non-null  object
#  1   trip_creation_time              144316 non-null  datetime64[ns]
#  2   route_schedule_uuid             144316 non-null  object
#  3   route_type                      144316 non-null  object
#  4   trip_uuid                       144316 non-null  object
#  5   source_center                   144316 non-null  object
#  6   source_name                     144316 non-null  object
#  7   destination_center              144316 non-null  object
#  8   destination_name                144316 non-null  object
#  9   od_start_time                   144316 non-null  datetime64[ns]
#  10  od_end_time                     144316 non-null  datetime64[ns]
# ...

# %%
route_type_distribution = df['route_type'].value_counts(normalize=True)*100
plt.pie(x = route_type_distribution, labels = route_type_distribution.index, autopct = '%.2f')
plt.show()

# %% [markdown]
# #Feature Engineering
# Let’s create a fearture “od_time_diff_hour” using od_start_time and od_end_time
# and convert it to hours.

# %%
df['segment_key'] = df['trip_uuid'] + df['source_center'] +df['destination_center']
segment_columns = ['segment_actual_time', 'segment_osrm_distance','segment_osrm_time']
for i in segment_columns:
  df[i + '_sum'] = df.groupby('segment_key').aggregate({i:'cumsum'})
df[[i+'_sum' for i in segment_columns]].head(10)
# Out:
#    segment_actual_time_sum  segment_osrm_distance_sum  segment_osrm_time_sum
# 0                     14.0                    11.9653                   11.0
# 1                     24.0                    21.7243                   20.0
# 2                     40.0                    32.5395                   27.0
# 3                     61.0                    45.5619                   39.0
# 4                     67.0                    49.4772                   44.0
# 5                     15.0                    12.1171                   11.0
# 6                     43.0                    21.2890                   17.0
# 7                     64.0                    35.8252                   28.0
# 8                     74.0                    47.1900                   38.0
# 9                    100.0                    53.2334                   44.0

# %%
# Aggregation at sub-journey level
segment_dict = {
'data' : 'first',
'trip_creation_time' : 'first',
'route_schedule_uuid' : 'first',
'route_type' : 'first',
'trip_uuid' : 'first',
'source_center' : 'first',
'source_name' : 'first',
'destination_center' : 'last',
'destination_name' : 'last',
'od_start_time' : 'first',
'od_end_time' : 'first',
'start_scan_to_end_scan' : 'first',
'actual_distance_to_destination' : 'last',
'actual_time' : 'last',
'osrm_time' : 'last',
'osrm_distance' : 'last',
'segment_actual_time_sum' : 'last',
'segment_osrm_distance_sum' : 'last',
'segment_osrm_time_sum' : 'last',
}
# Grouping mini trips and sorting them by time
segment_df = df.groupby('segment_key').aggregate(segment_dict).reset_index()
segment_df = segment_df.sort_values(by=['segment_key','od_end_time']).reset_index()
segment_df.head(5)
# Out:
#    index                                      segment_key      data  \
# 0      0  trip-153671041653548748IND209304AAAIND000000ACB  training
# 1      1  trip-153671041653548748IND462022AAAIND209304AAA  training
# 2      2  trip-153671042288605164IND561203AABIND562101AAA  training
# 3      3  trip-153671042288605164IND572101AAAIND561203AAB  training
# 4      4  trip-153671043369099517IND000000ACBIND160002AAC  training
#
#           trip_creation_time  \
# 0 2018-09-12 00:00:16.535741
# 1 2018-09-12 00:00:16.535741
# 2 2018-09-12 00:00:22.886430
# 3 2018-09-12 00:00:22.886430
# 4 2018-09-12 00:00:33.691250
#
#                                  route_schedule_uuid route_type  \
# 0  thanos::sroute:d7c989ba-a29b-4a0b-b2f4-288cdc6...        FTL
# 1  thanos::sroute:d7c989ba-a29b-4a0b-b2f4-288cdc6...        FTL
# 2  thanos::sroute:3a1b0ab2-bb0b-4c53-8c59-eb2a2c0...    Carting
# 3  thanos::sroute:3a1b0ab2-bb0b-4c53-8c59-eb2a2c0...    Carting
# ...

# %%
segment_df['od_time_diff_hour'] = (segment_df['od_end_time'] -segment_df['od_start_time']).dt.total_seconds()/60
segment_df.head(5)
# Out:
#    index                                      segment_key      data  \
# 0      0  trip-153671041653548748IND209304AAAIND000000ACB  training
# 1      1  trip-153671041653548748IND462022AAAIND209304AAA  training
# 2      2  trip-153671042288605164IND561203AABIND562101AAA  training
# 3      3  trip-153671042288605164IND572101AAAIND561203AAB  training
# 4      4  trip-153671043369099517IND000000ACBIND160002AAC  training
#
#           trip_creation_time  \
# 0 2018-09-12 00:00:16.535741
# 1 2018-09-12 00:00:16.535741
# 2 2018-09-12 00:00:22.886430
# 3 2018-09-12 00:00:22.886430
# 4 2018-09-12 00:00:33.691250
#
#                                  route_schedule_uuid route_type  \
# 0  thanos::sroute:d7c989ba-a29b-4a0b-b2f4-288cdc6...        FTL
# 1  thanos::sroute:d7c989ba-a29b-4a0b-b2f4-288cdc6...        FTL
# 2  thanos::sroute:3a1b0ab2-bb0b-4c53-8c59-eb2a2c0...    Carting
# 3  thanos::sroute:3a1b0ab2-bb0b-4c53-8c59-eb2a2c0...    Carting
# ...

# %% [markdown]
# **Aggregation at sub-journey level**

# %%
trip_dict = {
'data' : 'first',
'trip_creation_time' : 'first',
'route_schedule_uuid' : 'first',
'route_type' : 'first',
'trip_uuid' : 'first',
'source_center' : 'first',
'source_name' : 'first',
'destination_center' : 'last',
'destination_name' : 'last',
'start_scan_to_end_scan' : 'sum',
'od_time_diff_hour' : 'sum',
'actual_distance_to_destination' : 'sum',
'actual_time' : 'sum',
'osrm_time' : 'sum',
'osrm_distance' : 'sum',
'segment_actual_time_sum' : 'sum',
'segment_osrm_distance_sum' : 'sum',
'segment_osrm_time_sum' : 'sum',
}
trip_df = segment_df.groupby('trip_uuid').aggregate(trip_dict).reset_index(drop= True)
trip_df
# Out:
#            data         trip_creation_time  \
# 0      training 2018-09-12 00:00:16.535741
# 1      training 2018-09-12 00:00:22.886430
# 2      training 2018-09-12 00:00:33.691250
# 3      training 2018-09-12 00:01:00.113710
# 4      training 2018-09-12 00:02:09.740725
# ...         ...                        ...
# 14782      test 2018-10-03 23:55:56.258533
# 14783      test 2018-10-03 23:57:23.863155
# 14784      test 2018-10-03 23:57:44.429324
# 14785      test 2018-10-03 23:59:14.390954
# 14786      test 2018-10-03 23:59:42.701692
#
#                                      route_schedule_uuid route_type  \
# 0      thanos::sroute:d7c989ba-a29b-4a0b-b2f4-288cdc6...        FTL
# 1      thanos::sroute:3a1b0ab2-bb0b-4c53-8c59-eb2a2c0...    Carting
# 2      thanos::sroute:de5e208e-7641-45e6-8100-4d9fb1e...        FTL
# 3      thanos::sroute:f0176492-a679-4597-8332-bbd1c7f...    Carting
# 4      thanos::sroute:d9f07b12-65e0-4f3b-bec8-df06134...        FTL
# ...

# %%
trip_df[['actual_time','segment_actual_time_sum']].head(10)
# Out:
#    actual_time  segment_actual_time_sum
# 0       1562.0                   1548.0
# 1        143.0                    141.0
# 2       3347.0                   3308.0
# 3         59.0                     59.0
# 4        341.0                    340.0
# 5         61.0                     60.0
# 6         24.0                     24.0
# 7         64.0                     64.0
# 8        161.0                    161.0
# 9         23.0                     23.0

# %% [markdown]
# Notice that the values in these two columns don’t necessarily match. So, let’s test this hypothesis test.
#
# Step-1
#
# Null Hypothesis(H0) –> There is no difference in actual_time and segment_actual_time_sum.
#
# Alternate Hypothesis(HA) –> There is statistically significant difference in actual_time and segment_actual_time_sum.
#
# STEP-2 :
#
# Checking for basic assumpitons for the hypothesis
#
# Plot the histogram to visually see whether it follows normal distribution.
#
# If it doesn’t, use shapirowilk test to confirm.
#
# STEP-3:
#
# Define Test statistics; Distribution of T under H0.
#
# If the assumptions of T Test are met then we can proceed performing T Test for independent samples else we will perform the non parametric test equivalent to T Test for independent sample i.e., Mann-Whitney U test for two independent samples.
#
# STEP-4:
#
# Compute the p-value and compare with the value of alpha.
# alpha = 0.05
#
# STEP-5:
#
# Compare p-value and alpha.
#
# Based on p-value, we will accept or reject H0.
#
# p-val > alpha : Accept H0
#
# p-val < alpha : Reject H0

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.histplot(x='actual_time', data=trip_df)
plt.subplot(1,2,2)
sns.histplot(x='segment_actual_time_sum', data=trip_df)
plt.show()

# %%
# Neither of the graphs follow normal distribution So, let’s use shapiro-wilk test to confirm the same

from scipy.stats import shapiro

p_val_1 = shapiro(trip_df['actual_time'])[1]
p_val_2 = shapiro(trip_df['segment_actual_time_sum'])[1]
print(f'p_value of actual_time is \n {p_val_1} \nand p_value of segment_actual_time_sum is \n {p_val_2}')
# Out:
# p_value of actual_time is
#  1.562468303558549e-103
# and p_value of segment_actual_time_sum is
#  1.6746386852473887e-103

# %% [markdown]
# This confirms that the graphs don’t follow normal distribution.

# %%
from scipy.stats import wilcoxon

p_value = wilcoxon(trip_df['actual_time'],trip_df['segment_actual_time_sum'])[1]
if p_value >= 0.05:
  print('Fail to reject Null Hypothesis')
  print('There is no difference in actual_time and segment_actual_time_sum')
else:
  print('Reject Null Hypothesis')
  print('There is statistically significant difference in actual_time and segment_actual_time_sum.')
# Out:
# Reject Null Hypothesis
# There is statistically significant difference in actual_time and segment_actual_time_sum.

# %% [markdown]
# Let’s transaform destiname_name into more meaningful data
# Let’s break down destination_name into state and city

# %%
def parse_destination(destination_name):
    # Split state
    try:
        state = destination_name.split('(')[1][:-1]
    except IndexError:
        state = None

    # Split main part
    main_part = destination_name.split('(')[0]
    parts = main_part.split('_')

    city = parts[0] if len(parts) > 0 else None
    place = parts[1] if len(parts) >= 3 else (parts[0] if len(parts) == 2 else main_part.split(' ')[0])
    code = parts[-1] if len(parts) > 1 else None

    return pd.Series({
        'destination_state': state,
        'destination_city': city,
        'destination_place': place,
        'destination_code': code
    })

# Apply to DataFrame
trip_df[['destination_state', 'destination_city', 'destination_place', 'destination_code']] = trip_df['destination_name'].apply(parse_destination)

# %%
trip_df[['destination_state','destination_city','destination_place','destination_code']]
# Out:
#       destination_state destination_city destination_place destination_code
# 0         Uttar Pradesh           Kanpur           Central               6
# 1             Karnataka       Doddablpur          ChikaDPP               D
# 2               Haryana          Gurgaon          Bilaspur              HB
# 3           Maharashtra           Mumbai            MiraRd              IP
# 4             Karnataka           Sandur          WrdN1DPP               D
# ...                 ...              ...               ...              ...
# 14782            Punjab       Chandigarh          Mehmdpur               H
# 14783           Haryana        Faridabad           Blbgarh              DC
# 14784     Uttar Pradesh           Kanpur          GovndNgr              DC
# 14785        Tamil Nadu       Tirchchndr          Shnmgprm               D
# 14786         Karnataka           Sandur          WrdN1DPP               D
#
# [14787 rows x 4 columns]

# %%
top_states = trip_df.groupby('destination_state').aggregate({'trip_uuid':'count'}).reset_index().sort_values(by='trip_uuid',ascending=False)['destination_state']
print(f'The top 5 states are :{top_states[:5].values}')
top_cities = trip_df.groupby('destination_city').aggregate({'trip_uuid':'count'}).reset_index().sort_values(by='trip_uuid',ascending=False)['destination_city']
print(f'The top 5 cities are :{top_cities[:5].values}')
# Out:
# The top 5 states are :['Maharashtra' 'Karnataka' 'Haryana' 'Tamil Nadu' 'Gujarat']
# The top 5 cities are :['Bengaluru' 'Mumbai' 'Gurgaon' 'Delhi' 'Chennai']

# %%
states_trip_count = (
    trip_df.groupby('destination_state')
    .agg({'trip_uuid': 'count'})
    .reset_index()
    .sort_values(by='trip_uuid', ascending=False)
)

# Plotting the bar chart
plt.figure(figsize=(10, 6))
sns.barplot(
    x='destination_state',
    y='trip_uuid',
    data=states_trip_count,
    palette='viridis'
)
plt.title('Top States by Trip Count')
plt.xlabel('Destination State')
plt.ylabel('Number of Trips')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1764009105.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
city_trip_count=trip_df.groupby('destination_city').aggregate({'trip_uuid':'count'}).reset_index().sort_values(by='trip_uuid',ascending=False)[:10]

plt.figure(figsize=(10, 6))
sns.barplot(
    x='destination_city',
    y='trip_uuid',
    data=city_trip_count,
    palette='viridis'
)
plt.title('Top Cities by Trip Count')
plt.xlabel('Destination City')
plt.ylabel('Number of Trips')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1938304909.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
trip_df['trip_year'] = trip_df['trip_creation_time'].dt.year
trip_df['trip_month'] = trip_df['trip_creation_time'].dt.month
trip_df['trip_hour'] = trip_df['trip_creation_time'].dt.hour
trip_df['trip_day'] = trip_df['trip_creation_time'].dt.day
trip_df['trip_week'] = trip_df['trip_creation_time'].dt.isocalendar().week
trip_df['trip_dayofweek'] = trip_df['trip_creation_time'].dt.dayofweek
trip_df[['trip_year','trip_month','trip_hour','trip_day','trip_week','trip_dayofweek']].head()
# Out:
#    trip_year  trip_month  trip_hour  trip_day  trip_week  trip_dayofweek
# 0       2018           9          0        12         37               2
# 1       2018           9          0        12         37               2
# 2       2018           9          0        12         37               2
# 3       2018           9          0        12         37               2
# 4       2018           9          0        12         37               2

# %%
import calendar

# Map day numbers to full weekday names
trip_df['trip_dayofweek_name'] = trip_df['trip_dayofweek'].map(lambda x: calendar.day_name[x])

# Group by the new column
trip_df.groupby('trip_dayofweek_name').aggregate({'trip_uuid': 'count'}).reset_index()
# Out:
#   trip_dayofweek_name  trip_uuid
# 0              Friday       2057
# 1              Monday       1980
# 2            Saturday       2128
# 3              Sunday       1753
# 4            Thursday       2103
# 5             Tuesday       2035
# 6           Wednesday       2731

# %% [markdown]
# **The day that recieves peak orders is Wednesday**

# %% [markdown]
# # 📊 Outlier Detection and Remediation
# This process involves identifying data points that deviate significantly from the expected range and applying corrective measures to ensure data integrity and consistency.
#
# 1. Detection Method
# We used the Interquartile Range (IQR) technique to detect outliers:
#
# Q1: 25th percentile
#
# Q3: 75th percentile
#
# IQR = Q3 − Q1
#
#
# Outlier Thresholds:
#
# Lower Bound = Q1 − 1.5 × IQR
#
# Upper Bound = Q3 + 1.5 × IQR
#
# Any value outside this range is flagged as an outlier.
#
# 2. Treatment Strategy
#
# Outliers were treated using capping, where:
#
# Values below the lower bound were replaced with the lower bound.
# Values above the upper bound were replaced with the upper bound.
# This preserves the overall distribution while minimizing the impact of extreme values.

# %%
num_cols =['start_scan_to_end_scan','actual_distance_to_destination','actual_time',
'osrm_time', 'osrm_distance','segment_actual_time_sum',
'segment_osrm_distance_sum', 'segment_osrm_time_sum','od_time_diff_hour']

trip_df[num_cols].boxplot(rot=25, figsize=(20,8))
plt.show()

# %%
Q1 = trip_df[num_cols].quantile(0.25)
Q3 = trip_df[num_cols].quantile(0.75)
IQR = Q3-Q1


mask = (trip_df[num_cols] < (Q1 - 1.5 * IQR)) | (trip_df[num_cols] > (Q3 + 1.5 * IQR))
trip_df = trip_df[~mask.any(axis=1)]



trip_df[num_cols].boxplot(rot=25, figsize=(20,8))
plt.show()

# %% [markdown]
# # 📈 Insights
#
# **Limited Timeframe**
#
# The dataset spans only two months, which restricts the ability to draw conclusions about seasonal trends or long-term patterns such as month-over-month or year-over-year changes.
#
# **Data Discrepancy in Time Metrics**
# A notable difference between actual_time and segment_actual_time_sum suggests inconsistencies in data entry or logging practices.
#
#
# **Inconsistency in Predicted Time**
# A significant difference between segment_osrm_time_sum and osrm_time points to potential inaccuracies in the ML model’s time estimations.
#
# **Top Performing States**
# The five states contributing the most business are: Maharashtra, Karnataka, Haryana, Tamil Nadu, and Telangana.
#
# **Top Performing Cities**
# The leading cities in terms of order volume are: Bengaluru, Mumbai, Gurgaon, Delhi, and Hyderabad.
#
# **Peak Order Day**
# The highest number of orders are placed on Wednesdays, indicating a mid-week surge in demand.
#
# #✅ Recommendations
# **Enhance ML Model Accuracy**
#
# Invest in refining the machine learning model to improve predictions related to time and distance, thereby boosting operational efficiency.
#
# **Focus on High-Performing Regions**
#
# Prioritize infrastructure development and carrier enablement in top-performing states and cities to capitalize on existing demand and drive growth.
#
# **Optimize Mid-Week Operations**
# Prepare for increased order volumes on Wednesdays by scheduling extended shifts and deploying additional workforce to meet demand effectively.
